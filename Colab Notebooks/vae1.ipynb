# %%
pip install git+git://github.com/probtorch/probtorch
# Out:
# ...
#   Cloning git://github.com/probtorch/probtorch to /tmp/pip-req-build-bfk8difm
#   Running command git clone -q git://github.com/probtorch/probtorch /tmp/pip-req-build-bfk8difm
# ...
#   Created wheel for probtorch: filename=probtorch-0.0+4b7e140-cp36-none-any.whl size=24834 sha256=4ba0dc90e53dd7fb2bd461f9fb148097456c74f73ca494b1ec2196ede356cd81
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cps8c841/wheels/7a/d0/1a/4a78b78d88fd2ab06012b8ea26e43e15bb8856ba1cff3b4265
# Successfully built probtorch
# ...
